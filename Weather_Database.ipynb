# %%
# we are creating arrays of latitudes and longitudes, we'll declare each array as a variable.
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# adding/importing the python script from github repository on the citypy and city finder:

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 793

# %%
# Import the requests library.
import requests

# Import the API key.
from config2 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b9b485c465062a38450c2b490be840a3

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | buala
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | soltsy
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | salalah
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | sinnamary
# Processing Record 11 of Set 1 | husavik
# Processing Record 12 of Set 1 | waipawa
# Processing Record 13 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 1 | bengkulu
# Processing Record 15 of Set 1 | thompson
# Processing Record 16 of Set 1 | torbay
# Processing Record 17 of Set 1 | port hedland
# Processing Record 18 of Set 1 | teguise
# Processing Record 19 of Set 1 | luwuk
# Processing Record 20 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 1 | vila velha
# Processing Record 22 of Set 1 | yenagoa
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | norman wells
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | mount gambier
# Processing Record 27 of Set 1 | chibuto
# Processing Record 28 of Set 1 | caravelas
# Processing Record 29 of Set 1 | naranjal
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | hay river
# Processing Record 32 of Set 1 | zhangye
# Processing Record 33 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 1 | teknaf
# Processing Record 35 of Set 1 | sitka
# Processing Record 36 of Set 1 | danilovka
# Processing Record 37 of Set 1 | port blair
# Processing Record 38 of Set 1 | souris
# Processing Record 39 of Set 1 | havre-saint-pierre
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | prince rupert
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | lucea
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | ballstad
# City not found. Skipping...
# Processing Record 46 of Set 1 | praia da vitoria
# Processing Record 47 of Set 1 | merauke
# Processing Record 48 of Set 1 | lucapa
# Processing Record 49 of Set 1 | jalu
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | sabaudia
# Processing Record 2 of Set 2 | tuatapere
# Processing Record 3 of Set 2 | alofi
# Processing Record 4 of Set 2 | kapelle
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | ballina
# Processing Record 8 of Set 2 | osakarovka
# Processing Record 9 of Set 2 | goure
# Processing Record 10 of Set 2 | anadyr
# Processing Record 11 of Set 2 | lavrentiya
# Processing Record 12 of Set 2 | baryatino
# Processing Record 13 of Set 2 | portland
# Processing Record 14 of Set 2 | belyy yar
# Processing Record 15 of Set 2 | pevek
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | kaitangata
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | mehamn
# Processing Record 20 of Set 2 | whitehorse
# Processing Record 21 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 2 | indramayu
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | hillsboro
# Processing Record 25 of Set 2 | sioux falls
# Processing Record 26 of Set 2 | baracoa
# Processing Record 27 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 2 | escarcega
# Processing Record 29 of Set 2 | boguchany
# Processing Record 30 of Set 2 | sao filipe
# Processing Record 31 of Set 2 | mercedes
# Processing Record 32 of Set 2 | catamarca
# Processing Record 33 of Set 2 | georgetown
# Processing Record 34 of Set 2 | homer
# Processing Record 35 of Set 2 | klyuchi
# Processing Record 36 of Set 2 | saint george
# Processing Record 37 of Set 2 | severo-kurilsk
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | cervo
# Processing Record 40 of Set 2 | isangel
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | saint-philippe
# Processing Record 43 of Set 2 | alyangula
# Processing Record 44 of Set 2 | chandla
# Processing Record 45 of Set 2 | aklavik
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 2 | luanda
# Processing Record 50 of Set 2 | turinsk
# Processing Record 1 of Set 3 | matamoros
# Processing Record 2 of Set 3 | liniere
# City not found. Skipping...
# Processing Record 3 of Set 3 | byron bay
# Processing Record 4 of Set 3 | virginia beach
# Processing Record 5 of Set 3 | chongqing
# Processing Record 6 of Set 3 | nome
# Processing Record 7 of Set 3 | northam
# Processing Record 8 of Set 3 | anqing
# Processing Record 9 of Set 3 | coahuayana
# Processing Record 10 of Set 3 | bandarbeyla
# Processing Record 11 of Set 3 | albany
# Processing Record 12 of Set 3 | poso
# Processing Record 13 of Set 3 | lichuan
# Processing Record 14 of Set 3 | havoysund
# Processing Record 15 of Set 3 | mondovi
# Processing Record 16 of Set 3 | bredasdorp
# Processing Record 17 of Set 3 | san patricio
# Processing Record 18 of Set 3 | fairbanks
# Processing Record 19 of Set 3 | lebu
# Processing Record 20 of Set 3 | catemaco
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | collie
# Processing Record 23 of Set 3 | saskylakh
# Processing Record 24 of Set 3 | awjilah
# Processing Record 25 of Set 3 | nara
# Processing Record 26 of Set 3 | faanui
# Processing Record 27 of Set 3 | kondinskoye
# Processing Record 28 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 3 | nanakuli
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | victoria
# Processing Record 33 of Set 3 | koshurnikovo
# Processing Record 34 of Set 3 | vung tau
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | busselton
# Processing Record 37 of Set 3 | baoqing
# Processing Record 38 of Set 3 | new norfolk
# Processing Record 39 of Set 3 | hofn
# Processing Record 40 of Set 3 | chulman
# Processing Record 41 of Set 3 | tautira
# Processing Record 42 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 3 | chokurdakh
# Processing Record 44 of Set 3 | tigil
# Processing Record 45 of Set 3 | tual
# Processing Record 46 of Set 3 | khatanga
# Processing Record 47 of Set 3 | nikolskoye
# Processing Record 48 of Set 3 | bambous virieux
# Processing Record 49 of Set 3 | dalen
# Processing Record 50 of Set 3 | chuy
# Processing Record 1 of Set 4 | tyup
# Processing Record 2 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 4 | dong xoai
# Processing Record 4 of Set 4 | saint-augustin
# Processing Record 5 of Set 4 | puerto ayora
# Processing Record 6 of Set 4 | marion
# Processing Record 7 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 4 | tasiilaq
# Processing Record 9 of Set 4 | juba
# Processing Record 10 of Set 4 | hervey bay
# Processing Record 11 of Set 4 | garissa
# Processing Record 12 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 4 | eyl
# Processing Record 14 of Set 4 | cozumel
# Processing Record 15 of Set 4 | puerto narino
# Processing Record 16 of Set 4 | octeville
# Processing Record 17 of Set 4 | laguna
# Processing Record 18 of Set 4 | muros
# Processing Record 19 of Set 4 | kavieng
# Processing Record 20 of Set 4 | bethel
# Processing Record 21 of Set 4 | port elizabeth
# Processing Record 22 of Set 4 | sayyan
# Processing Record 23 of Set 4 | kipushi
# Processing Record 24 of Set 4 | cap-aux-meules
# Processing Record 25 of Set 4 | kathmandu
# Processing Record 26 of Set 4 | shalya
# Processing Record 27 of Set 4 | kudahuvadhoo
# Processing Record 28 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 4 | gzhatsk
# City not found. Skipping...
# Processing Record 30 of Set 4 | flinders
# Processing Record 31 of Set 4 | celestun
# Processing Record 32 of Set 4 | bure
# Processing Record 33 of Set 4 | jacareacanga
# Processing Record 34 of Set 4 | luderitz
# Processing Record 35 of Set 4 | payo
# Processing Record 36 of Set 4 | petropavlovka
# Processing Record 37 of Set 4 | esil
# Processing Record 38 of Set 4 | longyearbyen
# Processing Record 39 of Set 4 | ponta do sol
# Processing Record 40 of Set 4 | sulangan
# Processing Record 41 of Set 4 | kautokeino
# Processing Record 42 of Set 4 | pachmarhi
# Processing Record 43 of Set 4 | valle de santiago
# Processing Record 44 of Set 4 | gaya
# Processing Record 45 of Set 4 | dawei
# Processing Record 46 of Set 4 | cherskiy
# Processing Record 47 of Set 4 | antofagasta
# Processing Record 48 of Set 4 | nyurba
# Processing Record 49 of Set 4 | santa cruz
# Processing Record 50 of Set 4 | forrest city
# Processing Record 1 of Set 5 | astana
# Processing Record 2 of Set 5 | palauig
# Processing Record 3 of Set 5 | deep river
# Processing Record 4 of Set 5 | kruisfontein
# Processing Record 5 of Set 5 | preobrazheniye
# Processing Record 6 of Set 5 | westport
# Processing Record 7 of Set 5 | oussouye
# Processing Record 8 of Set 5 | timmins
# Processing Record 9 of Set 5 | arona
# Processing Record 10 of Set 5 | rongcheng
# Processing Record 11 of Set 5 | cayenne
# Processing Record 12 of Set 5 | fez
# Processing Record 13 of Set 5 | korla
# Processing Record 14 of Set 5 | cabo san lucas
# Processing Record 15 of Set 5 | arrifes
# Processing Record 16 of Set 5 | kelamangalam
# Processing Record 17 of Set 5 | port lincoln
# Processing Record 18 of Set 5 | geraldton
# Processing Record 19 of Set 5 | liverpool
# Processing Record 20 of Set 5 | san cristobal
# Processing Record 21 of Set 5 | fort nelson
# Processing Record 22 of Set 5 | labuhan
# Processing Record 23 of Set 5 | the pas
# Processing Record 24 of Set 5 | winnemucca
# Processing Record 25 of Set 5 | luganville
# Processing Record 26 of Set 5 | adrar
# Processing Record 27 of Set 5 | coihaique
# Processing Record 28 of Set 5 | namibe
# Processing Record 29 of Set 5 | saint anthony
# Processing Record 30 of Set 5 | souillac
# Processing Record 31 of Set 5 | broome
# Processing Record 32 of Set 5 | vao
# Processing Record 33 of Set 5 | ilulissat
# Processing Record 34 of Set 5 | dabakala
# Processing Record 35 of Set 5 | hakkari
# Processing Record 36 of Set 5 | luau
# Processing Record 37 of Set 5 | nishihara
# Processing Record 38 of Set 5 | pangnirtung
# Processing Record 39 of Set 5 | namwala
# Processing Record 40 of Set 5 | teya
# Processing Record 41 of Set 5 | vestbygda
# City not found. Skipping...
# Processing Record 42 of Set 5 | hasaki
# Processing Record 43 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 5 | bathsheba
# Processing Record 45 of Set 5 | acari
# Processing Record 46 of Set 5 | neuquen
# Processing Record 47 of Set 5 | upernavik
# Processing Record 48 of Set 5 | kot khai
# Processing Record 49 of Set 5 | turukhansk
# Processing Record 50 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 1 of Set 6 | touros
# Processing Record 2 of Set 6 | hovd
# Processing Record 3 of Set 6 | parakai
# Processing Record 4 of Set 6 | krasnogorskoye
# Processing Record 5 of Set 6 | katsuura
# Processing Record 6 of Set 6 | balikpapan
# Processing Record 7 of Set 6 | narsaq
# Processing Record 8 of Set 6 | barrow
# Processing Record 9 of Set 6 | vitim
# Processing Record 10 of Set 6 | mastic beach
# Processing Record 11 of Set 6 | sayansk
# Processing Record 12 of Set 6 | copiapo
# Processing Record 13 of Set 6 | bekhteyevka
# Processing Record 14 of Set 6 | clyde river
# Processing Record 15 of Set 6 | berlevag
# Processing Record 16 of Set 6 | evensk
# Processing Record 17 of Set 6 | porto murtinho
# Processing Record 18 of Set 6 | ranghulu
# Processing Record 19 of Set 6 | bluff
# Processing Record 20 of Set 6 | college
# Processing Record 21 of Set 6 | magadan
# Processing Record 22 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 6 | danielskuil
# Processing Record 24 of Set 6 | joshimath
# Processing Record 25 of Set 6 | sechelt
# Processing Record 26 of Set 6 | fallon
# Processing Record 27 of Set 6 | harper
# Processing Record 28 of Set 6 | dingli
# Processing Record 29 of Set 6 | poum
# Processing Record 30 of Set 6 | derzhavinsk
# Processing Record 31 of Set 6 | tucuman
# Processing Record 32 of Set 6 | jardim
# Processing Record 33 of Set 6 | mogadishu
# Processing Record 34 of Set 6 | shache
# Processing Record 35 of Set 6 | mar del plata
# Processing Record 36 of Set 6 | pangai
# Processing Record 37 of Set 6 | biak
# Processing Record 38 of Set 6 | yazman
# Processing Record 39 of Set 6 | east london
# Processing Record 40 of Set 6 | tucumcari
# Processing Record 41 of Set 6 | coracao de jesus
# Processing Record 42 of Set 6 | yellowknife
# Processing Record 43 of Set 6 | general roca
# Processing Record 44 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 45 of Set 6 | makhinjauri
# Processing Record 46 of Set 6 | fukue
# Processing Record 47 of Set 6 | brahmapuri
# City not found. Skipping...
# Processing Record 48 of Set 6 | vardo
# Processing Record 49 of Set 6 | tak
# Processing Record 50 of Set 6 | yulara
# Processing Record 1 of Set 7 | marfino
# Processing Record 2 of Set 7 | xinyang
# Processing Record 3 of Set 7 | tilichiki
# Processing Record 4 of Set 7 | lata
# Processing Record 5 of Set 7 | klungkung
# Processing Record 6 of Set 7 | churapcha
# Processing Record 7 of Set 7 | constancia
# Processing Record 8 of Set 7 | puerto ayacucho
# Processing Record 9 of Set 7 | kropotkin
# Processing Record 10 of Set 7 | aswan
# Processing Record 11 of Set 7 | agadez
# Processing Record 12 of Set 7 | yeppoon
# Processing Record 13 of Set 7 | ho chi minh city
# Processing Record 14 of Set 7 | kiunga
# Processing Record 15 of Set 7 | shilong
# Processing Record 16 of Set 7 | carnarvon
# Processing Record 17 of Set 7 | bjornevatn
# Processing Record 18 of Set 7 | enkoping
# Processing Record 19 of Set 7 | merritt
# Processing Record 20 of Set 7 | arlit
# Processing Record 21 of Set 7 | bonfim
# Processing Record 22 of Set 7 | dingle
# Processing Record 23 of Set 7 | lemesos
# City not found. Skipping...
# Processing Record 24 of Set 7 | uvira
# Processing Record 25 of Set 7 | airai
# Processing Record 26 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 27 of Set 7 | palu
# Processing Record 28 of Set 7 | te anau
# Processing Record 29 of Set 7 | udachnyy
# Processing Record 30 of Set 7 | klaksvik
# Processing Record 31 of Set 7 | warmbad
# Processing Record 32 of Set 7 | deputatskiy
# Processing Record 33 of Set 7 | sabha
# Processing Record 34 of Set 7 | neiafu
# Processing Record 35 of Set 7 | hambantota
# Processing Record 36 of Set 7 | nemuro
# Processing Record 37 of Set 7 | mujiayingzi
# Processing Record 38 of Set 7 | iqaluit
# Processing Record 39 of Set 7 | ryotsu
# Processing Record 40 of Set 7 | bykovo
# Processing Record 41 of Set 7 | ostrovnoy
# Processing Record 42 of Set 7 | xinyu
# Processing Record 43 of Set 7 | petatlan
# Processing Record 44 of Set 7 | ukiah
# Processing Record 45 of Set 7 | sambava
# Processing Record 46 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 47 of Set 7 | rincon
# Processing Record 48 of Set 7 | saint-francois
# Processing Record 49 of Set 7 | cururupu
# Processing Record 50 of Set 7 | bergen
# Processing Record 1 of Set 8 | george
# Processing Record 2 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 8 | naze
# Processing Record 4 of Set 8 | amahai
# Processing Record 5 of Set 8 | high prairie
# Processing Record 6 of Set 8 | pacific grove
# Processing Record 7 of Set 8 | grindavik
# Processing Record 8 of Set 8 | rio cuarto
# Processing Record 9 of Set 8 | constitucion
# Processing Record 10 of Set 8 | uarini
# Processing Record 11 of Set 8 | nuqui
# Processing Record 12 of Set 8 | lasa
# Processing Record 13 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 14 of Set 8 | bubaque
# Processing Record 15 of Set 8 | guarapari
# Processing Record 16 of Set 8 | ambon
# Processing Record 17 of Set 8 | woodhaven
# Processing Record 18 of Set 8 | fortuna
# Processing Record 19 of Set 8 | ekhabi
# Processing Record 20 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 8 | provideniya
# Processing Record 22 of Set 8 | honningsvag
# Processing Record 23 of Set 8 | macara
# Processing Record 24 of Set 8 | vila franca do campo
# Processing Record 25 of Set 8 | werdau
# Processing Record 26 of Set 8 | bud
# Processing Record 27 of Set 8 | meulaboh
# Processing Record 28 of Set 8 | nanchang
# Processing Record 29 of Set 8 | saint-pierre
# Processing Record 30 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 8 | takoradi
# Processing Record 32 of Set 8 | iconha
# Processing Record 33 of Set 8 | kodiak
# Processing Record 34 of Set 8 | cockburn town
# Processing Record 35 of Set 8 | payson
# Processing Record 36 of Set 8 | tateyama
# Processing Record 37 of Set 8 | ilyich
# Processing Record 38 of Set 8 | del rio
# Processing Record 39 of Set 8 | hearst
# Processing Record 40 of Set 8 | akyab
# Processing Record 41 of Set 8 | sept-iles
# Processing Record 42 of Set 8 | rocha
# Processing Record 43 of Set 8 | santa gertrudis
# Processing Record 44 of Set 8 | berdigestyakh
# Processing Record 45 of Set 8 | jerez
# Processing Record 46 of Set 8 | sobolevo
# Processing Record 47 of Set 8 | zhanjiang
# Processing Record 48 of Set 8 | puerto leguizamo
# Processing Record 49 of Set 8 | palmer
# Processing Record 50 of Set 8 | hillsborough
# Processing Record 1 of Set 9 | pisco
# Processing Record 2 of Set 9 | ayan
# Processing Record 3 of Set 9 | leningradskiy
# Processing Record 4 of Set 9 | kamien pomorski
# Processing Record 5 of Set 9 | bahia blanca
# Processing Record 6 of Set 9 | alice town
# Processing Record 7 of Set 9 | esperance
# Processing Record 8 of Set 9 | bethanien
# Processing Record 9 of Set 9 | fomboni
# Processing Record 10 of Set 9 | pontes e lacerda
# Processing Record 11 of Set 9 | minden
# Processing Record 12 of Set 9 | san quintin
# Processing Record 13 of Set 9 | kodinsk
# Processing Record 14 of Set 9 | hamilton
# Processing Record 15 of Set 9 | hohhot
# Processing Record 16 of Set 9 | olavarria
# Processing Record 17 of Set 9 | ngunguru
# Processing Record 18 of Set 9 | anchorage
# Processing Record 19 of Set 9 | agutaya
# Processing Record 20 of Set 9 | sibolga
# Processing Record 21 of Set 9 | zubtsov
# Processing Record 22 of Set 9 | ulaanbaatar
# Processing Record 23 of Set 9 | srednekolymsk
# Processing Record 24 of Set 9 | batagay-alyta
# Processing Record 25 of Set 9 | xinqing
# Processing Record 26 of Set 9 | eydhafushi
# Processing Record 27 of Set 9 | port hardy
# Processing Record 28 of Set 9 | nioro
# Processing Record 29 of Set 9 | cabedelo
# Processing Record 30 of Set 9 | normandin
# Processing Record 31 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 9 | nicoya
# Processing Record 33 of Set 9 | vostok
# Processing Record 34 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 35 of Set 9 | paamiut
# Processing Record 36 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 9 | tommot
# Processing Record 38 of Set 9 | denpasar
# Processing Record 39 of Set 9 | lompoc
# Processing Record 40 of Set 9 | plettenberg bay
# Processing Record 41 of Set 9 | loandjili
# Processing Record 42 of Set 9 | colares
# Processing Record 43 of Set 9 | taldan
# Processing Record 44 of Set 9 | fairlie
# Processing Record 45 of Set 9 | pemangkat
# Processing Record 46 of Set 9 | grimari
# City not found. Skipping...
# Processing Record 47 of Set 9 | sechura
# Processing Record 48 of Set 9 | bataipora
# Processing Record 49 of Set 9 | sokolo
# Processing Record 50 of Set 9 | khash
# Processing Record 1 of Set 10 | broken hill
# Processing Record 2 of Set 10 | yining
# Processing Record 3 of Set 10 | auki
# Processing Record 4 of Set 10 | najran
# Processing Record 5 of Set 10 | nyrob
# Processing Record 6 of Set 10 | vestmannaeyjar
# Processing Record 7 of Set 10 | bonthe
# Processing Record 8 of Set 10 | minudasht
# Processing Record 9 of Set 10 | gigmoto
# Processing Record 10 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 10 | porto novo
# Processing Record 12 of Set 10 | matara
# Processing Record 13 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 10 | huainan
# Processing Record 15 of Set 10 | viru
# Processing Record 16 of Set 10 | ust-omchug
# Processing Record 17 of Set 10 | fare
# Processing Record 18 of Set 10 | ziro
# Processing Record 19 of Set 10 | terra santa
# Processing Record 20 of Set 10 | olafsvik
# Processing Record 21 of Set 10 | bibiani
# Processing Record 22 of Set 10 | voh
# Processing Record 23 of Set 10 | shingu
# Processing Record 24 of Set 10 | guerrero negro
# Processing Record 25 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 27 of Set 10 | padang
# Processing Record 28 of Set 10 | mahebourg
# Processing Record 29 of Set 10 | acarau
# Processing Record 30 of Set 10 | dinard
# Processing Record 31 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 33 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 10 | mormugao
# Processing Record 35 of Set 10 | troitskoye
# Processing Record 36 of Set 10 | mount darwin
# Processing Record 37 of Set 10 | peniche
# Processing Record 38 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 10 | kitakata
# Processing Record 40 of Set 10 | asyut
# Processing Record 41 of Set 10 | sale
# Processing Record 42 of Set 10 | atar
# Processing Record 43 of Set 10 | nanortalik
# Processing Record 44 of Set 10 | kunya
# Processing Record 45 of Set 10 | talnakh
# Processing Record 46 of Set 10 | chivolo
# Processing Record 47 of Set 10 | teguldet
# Processing Record 48 of Set 10 | meihekou
# Processing Record 49 of Set 10 | dubuque
# Processing Record 50 of Set 10 | pitimbu
# Processing Record 1 of Set 11 | papetoai
# Processing Record 2 of Set 11 | nong khai
# Processing Record 3 of Set 11 | xian
# Processing Record 4 of Set 11 | fria
# Processing Record 5 of Set 11 | floro
# Processing Record 6 of Set 11 | belaya gora
# Processing Record 7 of Set 11 | olinda
# Processing Record 8 of Set 11 | havelock
# Processing Record 9 of Set 11 | xadani
# City not found. Skipping...
# Processing Record 10 of Set 11 | tromso
# Processing Record 11 of Set 11 | sola
# Processing Record 12 of Set 11 | san andres
# Processing Record 13 of Set 11 | yagodnoye
# Processing Record 14 of Set 11 | marquette
# Processing Record 15 of Set 11 | kambove
# Processing Record 16 of Set 11 | arman
# Processing Record 17 of Set 11 | vendome
# Processing Record 18 of Set 11 | barabinsk
# Processing Record 19 of Set 11 | coolum beach
# Processing Record 20 of Set 11 | paz de ariporo
# City not found. Skipping...
# Processing Record 21 of Set 11 | manuk mangkaw
# Processing Record 22 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 11 | glendive
# Processing Record 24 of Set 11 | upington
# Processing Record 25 of Set 11 | pafos
# Processing Record 26 of Set 11 | half moon bay
# Processing Record 27 of Set 11 | torgelow
# Processing Record 28 of Set 11 | kuminskiy
# Processing Record 29 of Set 11 | phalaborwa
# Processing Record 30 of Set 11 | tazovskiy
# Processing Record 31 of Set 11 | luzon
# Processing Record 32 of Set 11 | grand gaube
# Processing Record 33 of Set 11 | japura
# Processing Record 34 of Set 11 | kenai
# Processing Record 35 of Set 11 | san pedro
# Processing Record 36 of Set 11 | tuy hoa
# Processing Record 37 of Set 11 | lincoln
# Processing Record 38 of Set 11 | lengshuijiang
# Processing Record 39 of Set 11 | posse
# Processing Record 40 of Set 11 | praya
# Processing Record 41 of Set 11 | heishan
# Processing Record 42 of Set 11 | hobyo
# Processing Record 43 of Set 11 | bogande
# Processing Record 44 of Set 11 | chapais
# Processing Record 45 of Set 11 | sol-iletsk
# Processing Record 46 of Set 11 | moyale
# Processing Record 47 of Set 11 | mildura
# Processing Record 48 of Set 11 | tadine
# Processing Record 49 of Set 11 | henties bay
# Processing Record 50 of Set 11 | torit
# Processing Record 1 of Set 12 | olsztyn
# Processing Record 2 of Set 12 | gobabis
# Processing Record 3 of Set 12 | sao joao da barra
# Processing Record 4 of Set 12 | oksfjord
# Processing Record 5 of Set 12 | bonavista
# Processing Record 6 of Set 12 | bodden town
# Processing Record 7 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 8 of Set 12 | inta
# Processing Record 9 of Set 12 | babu
# Processing Record 10 of Set 12 | ust-kulom
# Processing Record 11 of Set 12 | mackay
# Processing Record 12 of Set 12 | riyadh
# Processing Record 13 of Set 12 | ixtapa
# Processing Record 14 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 12 | kutina
# Processing Record 16 of Set 12 | harrisonburg
# Processing Record 17 of Set 12 | honiara
# Processing Record 18 of Set 12 | bulgan
# Processing Record 19 of Set 12 | aasiaat
# Processing Record 20 of Set 12 | sur
# Processing Record 21 of Set 12 | kabanjahe
# Processing Record 22 of Set 12 | pangoa
# Processing Record 23 of Set 12 | gat
# Processing Record 24 of Set 12 | mackenzie
# Processing Record 25 of Set 12 | avera
# Processing Record 26 of Set 12 | kamenka
# Processing Record 27 of Set 12 | lozovik
# Processing Record 28 of Set 12 | boende
# Processing Record 29 of Set 12 | kosonsoy
# Processing Record 30 of Set 12 | kahului
# Processing Record 31 of Set 12 | alice springs
# Processing Record 32 of Set 12 | nador
# Processing Record 33 of Set 12 | alta floresta
# Processing Record 34 of Set 12 | ugoofaaru
# Processing Record 35 of Set 12 | asosa
# Processing Record 36 of Set 12 | bjerkvik
# Processing Record 37 of Set 12 | camacha
# Processing Record 38 of Set 12 | odessa
# Processing Record 39 of Set 12 | requena
# Processing Record 40 of Set 12 | port macquarie
# Processing Record 41 of Set 12 | churumuco
# City not found. Skipping...
# Processing Record 42 of Set 12 | kashi
# Processing Record 43 of Set 12 | savannakhet
# Processing Record 44 of Set 12 | richards bay
# Processing Record 45 of Set 12 | tiznit
# Processing Record 46 of Set 12 | kem
# Processing Record 47 of Set 12 | san cosme y damian
# Processing Record 48 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 12 | chadiza
# Processing Record 50 of Set 12 | naryan-mar
# Processing Record 1 of Set 13 | thaba-tseka
# Processing Record 2 of Set 13 | ahipara
# Processing Record 3 of Set 13 | saldanha
# Processing Record 4 of Set 13 | san ramon de la nueva oran
# Processing Record 5 of Set 13 | oranjemund
# Processing Record 6 of Set 13 | chany
# Processing Record 7 of Set 13 | rudbar
# Processing Record 8 of Set 13 | san joaquin
# Processing Record 9 of Set 13 | tabasalu
# Processing Record 10 of Set 13 | sioux lookout
# Processing Record 11 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 12 of Set 13 | vzmorye
# Processing Record 13 of Set 13 | kyabram
# Processing Record 14 of Set 13 | veraval
# Processing Record 15 of Set 13 | high rock
# Processing Record 16 of Set 13 | jambi
# Processing Record 17 of Set 13 | buritis
# Processing Record 18 of Set 13 | piacabucu
# Processing Record 19 of Set 13 | beyneu
# Processing Record 20 of Set 13 | uyar
# Processing Record 21 of Set 13 | ardakan
# Processing Record 22 of Set 13 | bombay
# Processing Record 23 of Set 13 | macalaya
# Processing Record 24 of Set 13 | sotouboua
# Processing Record 25 of Set 13 | matagami
# Processing Record 26 of Set 13 | san buenaventura
# Processing Record 27 of Set 13 | shimoda
# Processing Record 28 of Set 13 | kyzyl-suu
# Processing Record 29 of Set 13 | kenora
# Processing Record 30 of Set 13 | hue
# Processing Record 31 of Set 13 | lahat
# Processing Record 32 of Set 13 | crossville
# Processing Record 33 of Set 13 | cap malheureux
# Processing Record 34 of Set 13 | thunder bay
# Processing Record 35 of Set 13 | zhumadian
# Processing Record 36 of Set 13 | yarada
# Processing Record 37 of Set 13 | mayskiy
# Processing Record 38 of Set 13 | batagay
# Processing Record 39 of Set 13 | mindelo
# Processing Record 40 of Set 13 | burnie
# Processing Record 41 of Set 13 | phayao
# Processing Record 42 of Set 13 | mandera
# Processing Record 43 of Set 13 | mazamari
# Processing Record 44 of Set 13 | altay
# Processing Record 45 of Set 13 | banjarmasin
# Processing Record 46 of Set 13 | dudinka
# Processing Record 47 of Set 13 | kindu
# Processing Record 48 of Set 13 | dod ballapur
# Processing Record 49 of Set 13 | allanmyo
# City not found. Skipping...
# Processing Record 50 of Set 13 | rio gallegos
# Processing Record 1 of Set 14 | miraflores
# Processing Record 2 of Set 14 | rawson
# Processing Record 3 of Set 14 | rabo de peixe
# Processing Record 4 of Set 14 | el rodeo
# Processing Record 5 of Set 14 | pombas
# Processing Record 6 of Set 14 | penzance
# Processing Record 7 of Set 14 | mecca
# Processing Record 8 of Set 14 | samarai
# Processing Record 9 of Set 14 | bosaso
# Processing Record 10 of Set 14 | ketchikan
# Processing Record 11 of Set 14 | lewistown
# Processing Record 12 of Set 14 | walvis bay
# Processing Record 13 of Set 14 | divicani
# Processing Record 14 of Set 14 | murray
# Processing Record 15 of Set 14 | innisfail
# Processing Record 16 of Set 14 | puerto colombia
# Processing Record 17 of Set 14 | mirnyy
# Processing Record 18 of Set 14 | proletarsk
# Processing Record 19 of Set 14 | tezu
# Processing Record 20 of Set 14 | abu dhabi
# Processing Record 21 of Set 14 | asau
# Processing Record 22 of Set 14 | inhambane
# Processing Record 23 of Set 14 | namatanai
# Processing Record 24 of Set 14 | west bay
# Processing Record 25 of Set 14 | new glasgow
# Processing Record 26 of Set 14 | nabire
# Processing Record 27 of Set 14 | taunggyi
# Processing Record 28 of Set 14 | doha
# Processing Record 29 of Set 14 | damaturu
# Processing Record 30 of Set 14 | sneek
# Processing Record 31 of Set 14 | maryborough
# Processing Record 32 of Set 14 | dwarka
# Processing Record 33 of Set 14 | ferkessedougou
# Processing Record 34 of Set 14 | port said
# Processing Record 35 of Set 14 | nelson
# Processing Record 36 of Set 14 | mokhsogollokh
# Processing Record 37 of Set 14 | karwar
# Processing Record 38 of Set 14 | anahuac
# Processing Record 39 of Set 14 | satipo
# Processing Record 40 of Set 14 | los banos
# Processing Record 41 of Set 14 | ancud
# Processing Record 42 of Set 14 | big spring
# Processing Record 43 of Set 14 | jumla
# Processing Record 44 of Set 14 | lowestoft
# Processing Record 45 of Set 14 | itaituba
# Processing Record 46 of Set 14 | bama
# Processing Record 47 of Set 14 | ginda
# Processing Record 48 of Set 14 | jacmel
# Processing Record 49 of Set 14 | margate
# Processing Record 50 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 1 of Set 15 | mbandaka
# Processing Record 2 of Set 15 | bronnoysund
# Processing Record 3 of Set 15 | bandar maharani
# City not found. Skipping...
# Processing Record 4 of Set 15 | leo
# Processing Record 5 of Set 15 | lorengau
# Processing Record 6 of Set 15 | chokwe
# Processing Record 7 of Set 15 | dunedin
# Processing Record 8 of Set 15 | morgan city
# Processing Record 9 of Set 15 | mega
# Processing Record 10 of Set 15 | svetlogorsk
# Processing Record 11 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 12 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 15 | cidreira
# Processing Record 14 of Set 15 | mikun
# Processing Record 15 of Set 15 | seydi
# Processing Record 16 of Set 15 | gmund
# Processing Record 17 of Set 15 | para de minas
# Processing Record 18 of Set 15 | nan
# Processing Record 19 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 20 of Set 15 | savinskiy
# Processing Record 21 of Set 15 | kamaishi
# Processing Record 22 of Set 15 | acapulco
# Processing Record 23 of Set 15 | nadym
# Processing Record 24 of Set 15 | muyezerskiy
# Processing Record 25 of Set 15 | aurad
# Processing Record 26 of Set 15 | alvorada
# Processing Record 27 of Set 15 | fulitun
# City not found. Skipping...
# Processing Record 28 of Set 15 | andenes
# Processing Record 29 of Set 15 | lugovoy
# Processing Record 30 of Set 15 | naantali
# Processing Record 31 of Set 15 | amstelveen
# Processing Record 32 of Set 15 | port hawkesbury
# Processing Record 33 of Set 15 | murray bridge
# Processing Record 34 of Set 15 | eureka
# Processing Record 35 of Set 15 | komsomolskiy
# Processing Record 36 of Set 15 | okha
# Processing Record 37 of Set 15 | burkhala
# City not found. Skipping...
# Processing Record 38 of Set 15 | charters towers
# Processing Record 39 of Set 15 | mandalgovi
# Processing Record 40 of Set 15 | alihe
# Processing Record 41 of Set 15 | necochea
# Processing Record 42 of Set 15 | kayiry
# Processing Record 43 of Set 15 | la ronge
# Processing Record 44 of Set 15 | ayagoz
# Processing Record 45 of Set 15 | pringsewu
# Processing Record 46 of Set 15 | knoxville
# Processing Record 47 of Set 15 | altamont
# Processing Record 48 of Set 15 | derbent
# Processing Record 49 of Set 15 | zhuanghe
# Processing Record 50 of Set 15 | umm bab
# Processing Record 1 of Set 16 | maniitsoq
# Processing Record 2 of Set 16 | akcaabat
# Processing Record 3 of Set 16 | karakol
# Processing Record 4 of Set 16 | krasnoselkup
# Processing Record 5 of Set 16 | kidal
# Processing Record 6 of Set 16 | gisborne
# Processing Record 7 of Set 16 | hami
# Processing Record 8 of Set 16 | trelew
# Processing Record 9 of Set 16 | nagato
# Processing Record 10 of Set 16 | barroualie
# City not found. Skipping...
# Processing Record 11 of Set 16 | saint-georges
# Processing Record 12 of Set 16 | palenque
# Processing Record 13 of Set 16 | barranca de upia
# Processing Record 14 of Set 16 | yangambi
# Processing Record 15 of Set 16 | kihei
# Processing Record 16 of Set 16 | gao
# Processing Record 17 of Set 16 | inuvik
# Processing Record 18 of Set 16 | kalmunai
# Processing Record 19 of Set 16 | nampula
# Processing Record 20 of Set 16 | erdenet
# Processing Record 21 of Set 16 | tessalit
# Processing Record 22 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 16 | viedma
# Processing Record 24 of Set 16 | port-gentil
# Processing Record 25 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 16 | orzu
# Processing Record 27 of Set 16 | raudeberg
# Processing Record 28 of Set 16 | karpathos
# Processing Record 29 of Set 16 | kibakwe
# Processing Record 30 of Set 16 | filingue
# Processing Record 31 of Set 16 | kaeo
# Processing Record 32 of Set 16 | karlskoga
# Processing Record 33 of Set 16 | biltine
# Processing Record 34 of Set 16 | zhigansk
# Processing Record 35 of Set 16 | saiha
# Processing Record 36 of Set 16 | quatre cocos
# Processing Record 37 of Set 16 | macaboboni
# City not found. Skipping...
# Processing Record 38 of Set 16 | khadyzhensk
# Processing Record 39 of Set 16 | gushikawa
# Processing Record 40 of Set 16 | kottayam
# Processing Record 41 of Set 16 | mittersill
# Processing Record 42 of Set 16 | yar-sale
# Processing Record 43 of Set 16 | beringovskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# To check if we get a valid response (response 200), write a conditional expression:
# Create an endpoint URL for a city.
city_url = url + "&q=" + "gardelegen"
city_weather = requests.get(city_url)
print(city_weather)
# Out:
# <Response [200]>

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Hithadhoo  -0.6000   73.0833     82.67        68          98       13.24
# 1        Buala  -8.1450  159.5921     81.30        80          96        5.14
# 2        Vaini -21.2000 -175.2000     75.36        88          75        4.61
# 3       Soltsy  58.1239   30.3238     41.85        74           6        7.00
# 4  Port Alfred -33.5906   26.8910     60.24        70          17       24.70
# 5      Salalah  17.0151   54.0924     80.69        83          75        5.75
# 6        Kapaa  22.0752 -159.3190     80.92        69          40        7.00
# 7      Rikitea -23.1203 -134.9692     74.62        80          97       19.73
# 8    Sinnamary   5.3833  -52.9500     81.70        78          99       10.87
# 9      Husavik  66.0449  -17.3389     35.51        97         100        1.32
#
#   Country Current Description
# 0      MV     overcast clouds
# 1      SB     overcast clouds
# 2      TO       broken clouds
# 3      RU           clear sky
# 4      ZA          few clouds
# 5      OM       broken clouds
# 6      US          light rain
# 7      PF     overcast clouds
# 8      GF     overcast clouds
# 9      IS     overcast clouds

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
# new column order:
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp", "Cloudiness", "Humidity", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(17)
# Out:
#             City Country      Lat       Lng  Max Temp  Cloudiness  Humidity  \
# 0      Hithadhoo      MV  -0.6000   73.0833     82.67          98        68
# 1          Buala      SB  -8.1450  159.5921     81.30          96        80
# 2          Vaini      TO -21.2000 -175.2000     75.36          75        88
# 3         Soltsy      RU  58.1239   30.3238     41.85           6        74
# 4    Port Alfred      ZA -33.5906   26.8910     60.24          17        70
# 5        Salalah      OM  17.0151   54.0924     80.69          75        83
# 6          Kapaa      US  22.0752 -159.3190     80.92          40        69
# 7        Rikitea      PF -23.1203 -134.9692     74.62          97        80
# 8      Sinnamary      GF   5.3833  -52.9500     81.70          99        78
# 9        Husavik      IS  66.0449  -17.3389     35.51         100        97
# 10       Waipawa      NZ -41.4122  175.5153     56.44          24        67
# 11      Bengkulu      ID  -3.8004  102.2655     75.54          91        90
# 12      Thompson      CA  55.7435  -97.8558     50.16          75        81
# 13        Torbay      CA  47.6666  -52.7314     46.27          40        77
# 14  Port Hedland      AU -20.3167  118.5667     71.65          51        28
# 15       Teguise      ES  29.0605  -13.5640     70.02          75        68
# 16         Luwuk      ID  -0.9516  122.7875     78.12         100        88
#
#     Wind Speed Current Description
# 0        13.24     overcast clouds
# 1         5.14     overcast clouds
# 2         4.61       broken clouds
# 3         7.00           clear sky
# 4        24.70          few clouds
# 5         5.75       broken clouds
# 6         7.00          light rain
# 7        19.73     overcast clouds
# 8        10.87     overcast clouds
# 9         1.32     overcast clouds
# 10        7.25          few clouds
# 11        3.42          light rain
# 12        4.61       broken clouds
# 13       21.85    scattered clouds
# 14       12.66       broken clouds
# 15        9.22       broken clouds
# 16        5.35     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/citieschallenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
