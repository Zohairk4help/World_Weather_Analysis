# %%
# Create Heatmaps for Weather Parameters
# Import the dependencies.
import pandas as pd
import gmaps
import requests
from configDONTSHAREGITHUB import g_key

# %%
#!jupyter nbextension enable --py --sys-prefix gmaps
# %matplotlib inline

# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID      City Country                 Date      Lat       Lng  \
# 0        0   Nogales      MX  2021-10-10 00:07:25  31.3086 -110.9422
# 1        1  Qaqortoq      GL  2021-10-10 00:10:31  60.7167  -46.0333
# 2        2     Bluff      NZ  2021-10-10 00:10:31 -46.6000  168.3333
# 3        3    Namibe      AO  2021-10-10 00:10:32 -15.1961   12.1522
# 4        4   Rikitea      PF  2021-10-10 00:10:32 -23.1203 -134.9692
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     81.48        26           1       14.97
# 1     30.70        54          17        5.41
# 2     64.80        58          62        2.57
# 3     64.13        79           7        3.27
# 4     74.50        81          94       17.52

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# Create a Maximum Temperature Heatmap

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# nest create heat map using the general syntax as follows.
#1. Assign the locations to an array of latitude and longitude pairs.
locations = city_data_df[["Lat", "Lng"]]

# 2. Assign the weights variable to some values.
# temperatures = # an array of length equal to the locations array length
max-temp = city_data_df["Max Temp"]

# 3. Assign the figure variable to the gmaps.figure() attribute.
fig = gmaps.figure()

# 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.

heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])

# 5. Add the heatmap layer.
fig.add_layer(heat_layer)

# 6. Call the figure to plot the data.
fig
# Out:
#   File "<ipython-input-13-cae2663acfc5>", line 7
#     max-temp = city_data_df["Max Temp"]
#                                        ^
# SyntaxError: can't assign to operator

# %%
#1. Assign the locations to an array of latitude and longitude pairs.
locations = city_data_df[["Lat", "Lng"]]
# 2. Assign the weights variable to some values.
max_temp = city_data_df["Max Temp"]
# 3. Assign the figure variable to the gmaps.figure() attribute.
fig = gmaps.figure()
# 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
# 5. Add the heatmap layer.
fig.add_layer(heat_layer)
# 6. Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ###### Google heatmaps do not plot negative numbers. If you have a maximum temperature that is less than 0 °F, then you will get an InvalidWeightException error for this line of code: "heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)"

# %% [markdown]
# To remove the negative temperatures we can use a for loop to iterate through the max_temp and add the temperatures that are greater than 0 °F to a new list.
#
# Add a new cell above our previous code block, and then add the following code in the cell and run the cell.
#
# # Get the maximum temperature.

# %%
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
#1. Assign the locations to an array of latitude and longitude pairs.
locations = city_data_df[["Lat", "Lng"]]
# 2. Assign the weights variable to some values.
max_temp = city_data_df["Max Temp"]
# 3. Assign the figure variable to the gmaps.figure() attribute.
fig = gmaps.figure()
# 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.

heat_layer = gmaps.heatmap_layer(locations, weights=temps)


# 5. Add the heatmap layer.
fig.add_layer(heat_layer)
# 6. Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ###### Instead of using the for loop, we can perform a list comprehension within the heatmap_layer() function.
#
# Replace temps with our code for the list comprehension so our heat_layer code looks like the following:
#
# heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
#
# Rerun the cell.

# %%
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
#1. Assign the locations to an array of latitude and longitude pairs.
locations = city_data_df[["Lat", "Lng"]]
# 2. Assign the weights variable to some values.
max_temp = city_data_df["Max Temp"]
# 3. Assign the figure variable to the gmaps.figure() attribute.
fig = gmaps.figure()
# 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.

heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])


# 5. Add the heatmap layer.
fig.add_layer(heat_layer)
# 6. Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Adjust Heatmap Zoom, Intensity, and Point Radius

# %%
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
    


#1. Assign the locations to an array of latitude and longitude pairs.
locations = city_data_df[["Lat", "Lng"]]
# 2. Assign the weights variable to some values.
max_temp = city_data_df["Max Temp"]
# 3. Assign the figure variable to the gmaps.figure() attribute.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.

heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])


# 5. Add the heatmap layer.
fig.add_layer(heat_layer)
# 6. Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
    


#1. Assign the locations to an array of latitude and longitude pairs.
locations = city_data_df[["Lat", "Lng"]]
# 2. Assign the weights variable to some values.
max_temp = city_data_df["Max Temp"]
# 3. Assign the figure variable to the gmaps.figure() attribute.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.
# 
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)


# 5. Add the heatmap layer.
fig.add_layer(heat_layer)
# 6. Call the figure to plot the data.
fig

# If we scroll and zoom in on North America, we can see that the circles for the temperature are larger and the gradients show differences.
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create a Percent Humidity Heatmap
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create a Percent Cloudiness Heatmap

# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create a Percent wind speed Heatmap

# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Get Vacation Criteria
# Now, the cherry on top of the project: a feature on the app that allows customers to search for locations they want to travel based on their temperature preferences.

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %% [markdown]
# ###### Next, filter the maximum temperature column in the city_data_df DataFrame using logical operators to create a new DataFrame with the cities that meet the customer's criteria.

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(159)
# Out:
#      City_ID        City Country                 Date      Lat       Lng  \
# 0          0     Nogales      MX  2021-10-10 00:07:25  31.3086 -110.9422
# 7          7  Butaritari      KI  2021-10-10 00:10:33   3.0707  172.7902
# 10        10      Harper      LR  2021-10-10 00:09:17   4.3750   -7.7169
# 11        11      Avarua      CK  2021-10-10 00:05:53 -21.2078 -159.7750
# 13        13       Nioro      GM  2021-10-10 00:10:35  13.3500  -15.7500
# ..       ...         ...     ...                  ...      ...       ...
# 542      542      Majene      ID  2021-10-10 00:13:44  -3.5403  118.9707
# 543      543       Sabha      LY  2021-10-10 00:13:44  27.0377   14.4283
# 545      545     Amuntai      ID  2021-10-10 00:13:45  -2.4177  115.2494
# 548      548        Mana      GF  2021-10-10 00:13:46   5.6592  -53.7767
# 549      549        Surt      LY  2021-10-10 00:13:47  31.2089   16.5887
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       81.48        26           1       14.97
# 7       81.59        73          92       12.37
# 10      76.66        90          57        7.61
# 11      78.85        57          40        8.05
# 13      77.81        86          99        5.44
# ..        ...       ...         ...         ...
# 542     80.69        80         100        8.61
# 543     75.72        15           0       10.00
# 545     81.30        76          87        2.10
# 548     81.82        81         100       12.12
# 549     75.69        77          52       14.56
#
# [159 rows x 10 columns]

# %%
preferred_cities_df.isnull().sum()
# Out:
# City_ID       0
# City          0
# Country       1
# Date          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# dtype: int64

# %% [markdown]
# # Map Vacation Criteria
# Once the customers have filtered the database (DataFrame) based on their temperature preferences, show them a heatmap for the maximum temperature for the filtered cities. In addition, create a marker for each city that will display the name of the city, country code, maximum temperature, and name of a nearby hotel within three miles of the coordinates when the marker is clicked.

# %% [markdown]
# Make a copy of the preferred_cities_df DataFrame and name it hotel_df. For the hotel_df, keep the columns "City," "Country," "Max Temp," "Lat," and "Lng." Add a new column to the hotel_df DataFrame to hold the name of the hotel. this is because we want to retaion the original df

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp      Lat       Lng Hotel Name
# 0          Nogales      MX     81.48  31.3086 -110.9422
# 7       Butaritari      KI     81.59   3.0707  172.7902
# 10          Harper      LR     76.66   4.3750   -7.7169
# 11          Avarua      CK     78.85 -21.2078 -159.7750
# 13           Nioro      GM     77.81  13.3500  -15.7500
# 19          Atuona      PF     78.10  -9.8000 -139.0333
# 22       Kununurra      AU     85.98 -15.7667  128.7333
# 26        Bengkulu      ID     77.16  -3.8004  102.2655
# 29           Vaini      TO     78.96 -21.2000 -175.2000
# 42  Corpus Christi      US     82.96  27.8006  -97.3964

# %% [markdown]
# ##### Using the latitude and longitude and specific parameters, use the Google Cloud Map Search request to retrieve a hotel and add it to the Hotel Name column.

# %%
#Set the Parameters for a Nearby Search

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %% [markdown]
# ##### Practice Using a Fixed Latitude and Longitude

# %%
#  Dependencies and Setup
import requests
import gmaps
from configDONTSHAREGITHUB import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 7000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEBPDJ7Y-wNlbBWmHIoZkaOC14lsp9Yi4EBpKKhnCBDtm0V4z058m8OOnC_13RQs1coGTs1IiTPX-kVoRvb36DrTilcKGATQLHZWjEXsC_Jfy0QZsCIFIBjdAMZJluY8Mbf4BTXIfEgovp56XPLEB5BdoAaKBEepbrqRCu4U41QqnTY4zrJ2JCXn0vNKoCyriCAOY7E-TTkokuurKW8laSxl6h_jVdu1rsQgmt1hwe841scG6MOBnts-neKJbaicf39A_nZRbI4bVhayWtpShrKWufnKAAHDgwzQJZbDlxAk-iy1h4i-L1Yb2u2DXFppq0zWLwMCkJ-s6u458jwLGlPBR_GcGXc1IrqG9yW1zvqzSj2e73dDbaYxA_r5w1w_YomRkPA_EymxujfsmFFI0CzQ2b79ICAWfkskIIe22zkx1GL4Hv2jIpSK',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'],
#      'photo_reference': 'Aap_uEBXeuGxZbvzt2bLZiFBxwoDZdAjuZCDlnLWSRPyA9Fluu4_BnEivGRTV2YB7qdlDNfVk1C1p1moYLTGuCTzhR3yRZ9RW6sBbGbOZ9TeeSA_P97Vy8T8nS760IdbOsYNJe2gCwItPLIUEAsWHe5ZwbzyK5l317UNsO6_9lMd5p99yd1U',
#      'width': 5760}],
#    'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'plus_code': {'compound_code': 'V953+65 Paris, France',
#     'global_code': '8FW4V953+65'},
#    'rating': 4.2,
#    'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'spa',
#     'lodging',
#     'bar',
#     'gym',
#     'health',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total':
],
#    'place_id': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'plus_code': {'compound_code': 'V84R+68 Paris, France',
#     'global_code': '8FW4V84R+68'},
#    'rating': 4.3,
#    'reference': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 701,
#    'vicinity': '53 ter Quai des Grands Augustins, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8663519, 'lng': 2.3606461},
#     'viewport': {'northeast': {'lat': 48.86775308029149,
#       'lng': 2.361905130291502},
#      'southwest': {'lat': 48.8650551197085, 'lng': 2.359207169708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Paris France Hôtel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2673,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102332962500946068613">Paris France Hôtel</a>'],
#      'photo_reference': 'Aap_uEBLwHAypABbw34dcYvcsg8LM-06SCtSwxELA6cIuV2bqHxa940aJjac5qb7R5IqP3uOCOGm56WME1f4No4HRS8BNi5wf7Lt0dkqEVef9h2qHI17_Skw-7vlEVAkG9O1ZnAXUMeRSErD0K-YSw7LiRTj-Wx_ItSV4oaztEZU8SwNAmrF',
#      'width': 3463}],
#    'place_id': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'plus_code': {'compound_code': 'V986+G7 Paris, France',
#     'global_code': '8FW4V986+G7'},
#    'rating': 4.3,
#    'reference': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 383,
#    'vicinity': '72 Rue de Turbigo, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86386539999999, 'lng': 2.3325488},
#     'viewport': {'northeast': {'lat': 48.8650759802915,
#       'lng': 2.333775730291502},
#      'southwest': {'lat': 48.8623780197085, 'lng': 2.331077769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Regina Louvre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3700,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109908333790946649027">Hôtel Regina Louvre</a>'],
#      'photo_reference': 'Aap_uEB-F3tzKRYIAhOsV568mezLLn9HAlkgq8gfZeZdG9kI_3c1emilNmaWNk98XwHE7VNjheSJFdr5PeWcqW14pbVGvvtSZJuUTceRyUdlRbwyR-933log3qeuSgGQ0Nd0NsapkI_HklJu6XqQa6dDqWA_LhK5SqCO15ZJWd9fuMN8_igs',
#      'width': 5550}],
#    'place_id': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'plus_code': {'compound_code': 'V87M+G2 Paris, France',
#     'global_code': '8FW4V87M+G2'},
#    'rating': 4.4,
#    'reference': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 508,
#    'vicinity': '2 Place des Pyramides, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84795229999999, 'lng': 2.370869},
#     'viewport': {'northeast': {'lat': 48.8492035302915,
#       'lng': 2.372290080291501},
#      'southwest': {'lat': 48.8465055697085, 'lng': 2.369592119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'ibis Paris Gare de Lyon Ledru Rollin 12ème',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2048,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101181280085797863615">Kevin Nguyen</a>'],
#      'photo_reference': 'Aap_uEB3Ei2AhnSYFGZOpCau446QAlsJSzDBGFNmqBjHHo5phHHJgTHBpymTWlqfgijtsaPoggbpFEJ0Uxsc-g1ChAC7oREeGYMqo5foFgTm8kGzFMWQa8lI4AoI8d8lbvLqN7KTDUGzTwBngNIC2L0C5azZoGr1jWCHXzB9BAbqEXFeVgd4',
#      'width': 1536}],
#    'place_id': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'plus_code': {'compound_code': 'R9XC+58 Paris, France',
#     'global_code': '8FW4R9XC+58'},
#    'rating': 4,
#    'reference': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 827,
#    'vicinity': '41/43 Avenue Ledru Rollin, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8710647, 'lng': 2.34991},
#     'viewport': {'northeast': {'lat': 48.87241888029151,
#       'lng': 2.351188530291502},
#      'southwest': {'lat': 48.86972091970851, 'lng': 2.348490569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel des Comédies Paris',
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114696623290303183213">Noble</a>'],
#      'photo_reference': 'Aap_uEDUOlcutow6g5RZI-0iN7-bVC_wQVc16TvJC-xs_vMYnBa0Cl6QSrycq-X-E0zQv4W75GfLV8tAbcfoXfLihgvI1yzOSrDLd-JKswgeXtdp4HQqO2sVZvkMnJXPdbu7d8MSGlk8M-8l6hEp40PHGXSQKiroSBK3DuYxgsY1LJ32JN1c',
#      'width': 3000}],
#    'place_id': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'plus_code': {'compound_code': 'V8CX+CX Paris, France',
#     'global_code': '8FW4V8CX+CX'},
#    'rating': 4.2,
#    'reference': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total':

#      'width': 1600}],
#    'place_id': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'plus_code': {'compound_code': 'V8CQ+CH Paris, France',
#     'global_code': '8FW4V8CQ+CH'},
#    'rating': 3.7,
#    'reference': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 140,
#    'vicinity': "4 Rue d'Amboise, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8524547, 'lng': 2.3472064},
#     'viewport': {'northeast': {'lat': 48.8538838802915,
#       'lng': 2.348601530291502},
#      'southwest': {'lat': 48.8511859197085, 'lng': 2.345903569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Esmeralda',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114852001362047630790">Georgia Hentze</a>'],
#      'photo_reference': 'Aap_uECa6sY3xciUonLxP0aAUJ6ZLgLHTU8m7BFPldrSvThAlFsMm67GjgBmeXi5aH96gVHKK_nr_VbLSFiQn17-cymf1OG73NSC6fv_SZ9n3nVobimvKt5Lh-hG8JkaZ4LdLdpI9r_UL5uDNZcWR_bFbXwMFrhJ0v8KyzThQ-XcxBmQCvqb',
#      'width': 3024}],
#    'place_id': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'plus_code': {'compound_code': 'V82W+XV Paris, France',
#     'global_code': '8FW4V82W+XV'},
#    'rating': 4.1,
#    'reference': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 145,
#    'vicinity': '4 Rue Saint-Julien le Pauvre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8530901, 'lng': 2.3447174},
#     'viewport': {'northeast': {'lat': 48.8544403302915,
#       'lng': 2.346001280291502},
#      'southwest': {'lat': 48.8517423697085, 'lng': 2.343303319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Albe Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117571951379278191466">Albe Hotel Saint Michel</a>'],
#      'photo_reference': 'Aap_uEBztJBCMGzxTCstnJe9XknLjbV2YxmTwjKp8ntDveBUuNJ_sxcF7ZEbAYyd0SqZLnpeynnYlbHO9G6pntZq_elLaX3NKk16nHJNWwXCa-txOsrshCE5iidBONERBQbpT3JhKOqgaI9bTOfEnZgrUX1bQWtZFW-1kWzrIV1CPCWPMbJF',
#      'width': 1600}],
#    'place_id': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'plus_code': {'compound_code': 'V83V+6V Paris, France',
#     'global_code': '8FW4V83V+6V'},
#    'rating': 4.4,
#    'reference': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 330,
#    'vicinity': '1 Rue de la Harpe, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8499443, 'lng': 2.3462474},
#     'viewport': {'northeast': {'lat': 48.8512737302915,
#       'lng': 2.347507380291502},
#      'southwest': {'lat': 48.8485757697085, 'lng': 2.344809419708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Home Latin',
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108547915404801536469">Jp Homma</a>'],
#      'photo_reference': 'Aap_uECzahWo0vMgjciOigxvI_w6glNzW9HR65WDK22W478Rn62V1UERHI1D6kPtwU2cOK2qqKha6S8t18AH3YEXMopQ99K5QLzNxW7h_cGZ0_gj1mhSES7S-FDVnseTQmaHY9pIT0OC2oXbSfN6mfauWo5OcegulmLVjkpozJFJ8RUnuVe1',
#      'width': 4608}],
#    'place_id': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'plus_code': {'compound_code': 'R8XW+XF Paris, France',
#     'global_code': '8FW4R8XW+XF'},
#    'rating': 3.5,
#    'reference': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 280,
#    'vicinity': '15-17 Rue du Sommerard, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85473870000001, 'lng': 2.3395455},
#     'viewport': {'northeast': {'lat': 48.8561127802915,
#       'lng': 2.340820530291502},
#      'southwest': {'lat': 48.8534148197085, 'lng': 2.338122569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Hôtel d'Aubusson",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3568,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115702439863948549296">Hôtel d&#39;Aubusson Paris</a>'],
#      'photo_reference': 'Aap_uEB4GlA-5BjWBzL5xM4orNUj2DAjXK5guEmyYrmoU0ZsUsSSBoTuQs9veidkvXzia1a399N70awC_dCMZiu9JpbCY7vdC3DCrYZ-ChSmdBKzzrHYjXjHs4rfdVHF5BdDEnJa4C0uZYexLtbN0A1f66l9vtNFFtJptcl9MD8wYLNaSBu9',
#      'width': 5353}],
#    'place_id': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'plus_code': {'compound_code': 'V83Q+VR Paris, France',
#     'global_code': '8FW4V83Q+VR'},
#    'rating': 4.7,
#    'reference': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 292,
#    'vicinity': '33 Rue Dauphine, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85184049999999, 'lng': 2.3448082},
#     'viewport': {'northeast': {'lat': 48.8531470802915,
#       'lng': 2.346121880291502},
#      'southwest': {'lat': 48.8504491197085, 'lng': 2.343423919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2362,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107542132357877294567">Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France</a>'],
#      'photo_reference': 'Aap_uEDivnqVvxntnbmf0HRM_khC2sJUqW_ZZNIVAQXP9xs70_JwhiwnXyG_LGkELKXCoFZas_TXZYRtZR0i6fgWUZ30lKuKmgrMb2CUtcW-1n8JgzWt7rfGcUvsZhi7eE5lZFGp4jJHo48jzNqY3PC25BYQ11_yRzOkIiZmtAh4cJyZiEj3',
#      'width': 3776}],
#    'place_id': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'plus_code': {'compound_code': 'V82V+PW Paris, France',
#     'global_code': '8FW4V82V+PW'},
#    'rating': 4.6,
#    'reference': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 139,
#    'vicinity': '22 Rue de la Parcheminerie, Paris'}],
#  'status': 'OK'}

# %% [markdown]
# Scroll through the information. Below the next_page_token is a results dictionary. To get all the hotels in the results dictionary we can get the length of this dictionary by using, len(hotels["results"]).

# %%
len(hotels["results"])
# Out:
# 20

# %% [markdown]
# # After finding "'Hôtel Duo'" to be the 0 index in the hotels df parameters, Iterate Through hotel_df DataFrame

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-fb4b837962f0> in <module>
#      13     hotels = requests.get(base_url, params=params).json()
#      14     # Grab the first hotel from the results and store the name.
# ---> 15     hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
#
# IndexError: list index out of range

# %% [markdown]
# ###### Recall that when trying to parse the data from an API request, we need to use a try-except block to handle the error with a statement and continue the retrieval.

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()

   # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head(10)
# Out:
#               City Country  Max Temp      Lat       Lng  \
# 0          Nogales      MX     81.48  31.3086 -110.9422
# 7       Butaritari      KI     81.59   3.0707  172.7902
# 10          Harper      LR     76.66   4.3750   -7.7169
# 11          Avarua      CK     78.85 -21.2078 -159.7750
# 13           Nioro      GM     77.81  13.3500  -15.7500
# 19          Atuona      PF     78.10  -9.8000 -139.0333
# 22       Kununurra      AU     85.98 -15.7667  128.7333
# 26        Bengkulu      ID     77.16  -3.8004  102.2655
# 29           Vaini      TO     78.96 -21.2000 -175.2000
# 42  Corpus Christi      US     82.96  27.8006  -97.3964
#
#                                            Hotel Name
# 0                               Hotel Marqués De Cima
# 7                                  Isles Sunset Lodge
# 10                                        Screensaver
# 11                                      Sunset Resort
# 13                                        Manka Kunda
# 19                                        Villa Enata
# 22                                    Hotel Kununurra
# 26                               Grage Hotel Bengkulu
# 29                                Keleti Beach Resort
# 42  Holiday Inn Corpus Christi Downtown Marina, an...

# %% [markdown]
# ###### Our final task will be to add pop-up markers with hotel information to a heatmap.

# %% [markdown]
# ### Create a Maximum Temperature Heatmap from a Hotel DataFrame

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ###### add the markers for each city on top of the heatmap, so edit the above code

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ##### add a pop-up marker for each city that displays the hotel name, city name, country, and maximum temperature
# From the gmaps documentation on how to add markers (Links to an external site.), we need to add an info_box_template that has the following syntax.

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
